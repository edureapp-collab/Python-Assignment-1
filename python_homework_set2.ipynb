# %% [markdown]
# # Python Homework Notebook – Set 2
# This notebook contains **new** questions for practice on **operators**, **conditional statements**, **functions**, and **classes**.
#
# Students should write code in the provided cells.

# %% [markdown]
# ## 1. Operators
# ### Q1: Write a program to calculate the area of a rectangle using `*` operator.

# %%
# Write your code here

# %% [markdown]
# ### Q2: Use floor division `//` to find how many full dozens are in a given number of eggs.

# %%
# Write your code here

# %% [markdown]
# ## 2. Conditional Statements
# ### Q3: Check if a student's score is **Pass**, **Fail**, or **Distinction**.
# - Distinction: score ≥ 90
# - Pass: score ≥ 40
# - Fail: score < 40

# %%
# Write your code here

# %% [markdown]
# ### Q4: Write a program to check whether a given year is a leap year.

# %%
# Write your code here

# %% [markdown]
# ## 3. Functions
# ### Q5: Write a function that takes two numbers and returns their average.

# %%
# Write your code here

# %% [markdown]
# ### Q6: Write a function that takes a string and returns how many vowels are in it.

# %%
# Write your code here

# %% [markdown]
# ## 4. Classes
# ### Q7: Create a class `Car` with attributes **brand** and **model**, then print them using an object.

# %%
# Write your code here

# %% [markdown]
# ### Q8: Create a class `MathOperations` with a method that returns the product of two numbers.

# %%
# Write your code here
